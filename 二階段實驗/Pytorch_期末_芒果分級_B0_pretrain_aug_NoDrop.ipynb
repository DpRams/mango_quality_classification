# %%
# # This mounts your Google Drive to the Colab VM.
# from google.colab import drive
# drive.mount('/content/drive')
# !cp "/content/drive/MyDrive/AI芒果辨識競賽/C1-P1_Train Dev.rar" "/content/"

# %%
# !mkdir "mango"
# !unrar x "C1-P1_Train Dev.rar" "mango"

# %%
DATA_DIR = 'data/mango'

# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"

import shutil
import cv2
from PIL import Image
from tqdm.notebook import tqdm
import numpy as np
import pandas as pd
from torchvision.io import read_image
from torchvision import transforms, datasets
from torchvision.models import efficientnet_b3, efficientnet_b0, efficientnet_b6
import torch
from torch.utils.data import Dataset
from torch.nn import ZeroPad2d
import matplotlib.pyplot as plt
import tensorflow as tf

PADDING_SIZE = 1536
IMG_SHAPE = (224, 224)
# BATCH_SIZE = 512
OUTPUT_CLASSES = 3
MEAN = [55.49694383, 60.2820865, 82.53554147]
STD = [65.72940478, 67.66902771, 87.42390442]
dtype = torch.float32

# %%
class History:
    def __init__(self):
        self.train_loss = []
        self.val_loss = []
        self.train_acc = []
        self.val_acc = []
        self.running_loss = 0
        self.running_acc = 0
        
    def batch_train(self, batch_loss, batch_acc):
        self.running_loss += batch_loss
        self.running_acc += batch_acc
        
    def epoch_train(self, batch_num):
        self.train_loss.append(self.running_loss / batch_num)
        self.train_acc.append(self.running_acc / batch_num)
        self.running_loss = 0
        self.running_acc = 0
        
    def epoch_val(self, val_loss, val_acc):
        self.val_loss.append(val_loss)
        self.val_acc.append(val_acc)


def calculate_accuracy(y_pred, y_true):
    # y_pred y_true要是2D array (每筆資料的label的onehot encoding)
    y_pred = y_pred.argmax(axis=1)
    y_true = y_true.argmax(axis=1)
    correct = (y_pred == y_true).float().sum()
    accuracy = correct / len(y_true)
    return float(accuracy)

def validation(model, loader):
    num_correct = 0
    num_samples = 0
    loss = 0.0
    all_y_true = []
    all_y_pred = []
    model.eval()  # set model to evaluation mode
    with torch.no_grad():
        for x, y in loader:
            x = x.to(device=device, dtype=dtype)  # move to device, e.g. GPU
            y_true = y.to(device=device, dtype=dtype).argmax(axis=1)
            scores = model(x)      
            _, preds = scores.max(1)
            num = preds.size(0)
            loss += CE_loss(scores, y_true) * num
            
            all_y_true.append(y_true)
            all_y_pred.append(preds)

            num_correct += (preds == y_true).sum()
            num_samples += num
    acc = float(num_correct) / num_samples
    loss = float(loss / num_samples)
    return acc, loss, (all_y_true, all_y_pred)

# %%
def read_data(which="train"):
    data_dir = None
    y = None
    if which == "train":
        data_dir = os.path.join(DATA_DIR, "C1-P1_Train")
        label_csv = os.path.join(DATA_DIR, "train.csv")
    elif which == "test":
        data_dir = os.path.join(DATA_DIR, "C1-P1_Dev")
        label_csv = os.path.join(DATA_DIR, "dev.csv")
    else:
        print('input should be train or test')
        return

    X = []
    y = pd.get_dummies(pd.read_csv(label_csv, header=None)[1]).to_numpy()

    filenames = sorted(os.listdir(data_dir))  
    for filename in tqdm(filenames):
        fpath = os.path.join(data_dir, filename)
        img = cv2.imread(fpath)
        h,w,_ = img.shape
        top = int((PADDING_SIZE - h)/2)
        botoom = PADDING_SIZE - h - top
        left = int((PADDING_SIZE - w)/2)
        right = PADDING_SIZE - w - left

        # img = (img - MEAN) / STD
        img = img.astype(np.float32)
        img = cv2.copyMakeBorder(img, top, botoom, left, right, cv2.BORDER_CONSTANT)
        img[top:PADDING_SIZE-botoom, left:PADDING_SIZE-right] = \
          (img[top:PADDING_SIZE-botoom, left:PADDING_SIZE-right] - MEAN) / STD

        img = cv2.resize(img, IMG_SHAPE)
        X.append(img)
        # display(Image.fromarray(img[:,:,::-1]))
        # break
  
    X = np.array(X)
    return X, y

# %%
# %%time
# X_train, y_train = read_data(which="train")
# X_test, y_test = read_data(which="test")

npy_dir = "./data"
X_train = np.load(os.path.join(npy_dir, 'X_train.npy'))
y_train = np.load(os.path.join(npy_dir, 'y_train.npy'))
X_test = np.load(os.path.join(npy_dir, 'X_test.npy'))
y_test = np.load(os.path.join(npy_dir, 'y_test.npy'))
# Out:
# Wall time: 936 ms

# %%
# npy_dir = "./data"
# np.save(os.path.join(npy_dir, 'X_train.npy'), X_train)
# np.save(os.path.join(npy_dir, 'y_train.npy'), y_train)
# np.save(os.path.join(npy_dir, 'X_test.npy'), X_test)
# np.save(os.path.join(npy_dir, 'y_test.npy'), y_test)

# %%
# from google.colab.patches import cv2_imshow
plt.figure(figsize=(12,8))
for i, img in enumerate(X_train[:3]):
#     print(f"第{i+1}張圖片:")
#     cv2_imshow(img*STD+MEAN)
#     img = img*STD+MEAN
#     img = img.astype(np.int32)
    ax = plt.subplot(1, 3, i+1)    
    plt.title(f"figure {i+1}")
    ax.imshow(img[:,:,::-1])

#     plt.imshow(img[:,:,::-1])

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(
    X_train, y_train, test_size=0.1, random_state=1028)

# %%
print("X_train.shape", X_train.shape)
print("y_train.shape", y_train.shape)
print("X_val.shape", X_val.shape)
print("y_val.shape", y_val.shape)
print("X_test.shape", X_test.shape)
print("y_test.shape", y_test.shape)
# Out:
# X_train.shape (5040, 224, 224, 3)
# y_train.shape (5040, 3)
# X_val.shape (560, 224, 224, 3)
# y_val.shape (560, 3)
# X_test.shape (800, 224, 224, 3)
# y_test.shape (800, 3)

# %% [markdown]
# mean [55.49694383 60.2820865  82.53554147]
#
# std [65.72940478 67.66902771 87.42390442]

# %%
# print("mean", X_train.mean(axis=(0,1,2)))
# print("std", np.sqrt(X_train.var(axis=(0,1,2))))

# %%
def pre_processing(X):
    X = X[:,:,:,::-1].transpose(0,3,1,2)
    X = torch.tensor(X.copy(), dtype=dtype)
    # X = torch.tensor(X, dtype=dtype)
    # f_norm = transforms.Normalize(
    #           mean=[55.49694383, 60.2820865, 82.53554147],
    #           std=[65.72940478, 67.66902771, 87.42390442])
    # X = f_norm(X)
    return X

class MangoDataset(Dataset):
    def __init__(self, X, y, transform=None, target_transform=None):
        # self.X = pre_processing(X)
        self.X = X
        self.y = torch.tensor(y)
        self.transform = transform
        self.target_transform = target_transform
        
    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        image =  self.X[idx]
        image = image[:,:,::-1].transpose(2,0,1)
        image = torch.tensor(image.copy(), dtype=dtype)
        label = self.y[idx]
        if self.transform:
            image = self.transform(image)
        if self.target_transform:
            label = self.target_transform(label)
        return image, label

# %%
data_aug = [
  transforms.RandomCrop((200, 200)),
  transforms.RandomHorizontalFlip(p=0.5),
  transforms.RandomVerticalFlip(p=0.5),
  transforms.RandomAffine(degrees=50, translate=(0.15, 0.15)),
#   transforms.ColorJitter(brightness=0.1, contrast=0.1, saturation=0.1),
]

transform = transforms.Compose([
  transforms.RandomOrder(data_aug),
])

# %%
X_train.shape
# Out:
# (5040, 224, 224, 3)

# %%
import torch.nn as nn
import torch.nn.functional as F

def fc_bc_relu_dropout(in_size, out_size, p=0.5):
    return nn.Sequential(
        nn.Linear(in_size, out_size),
        nn.BatchNorm1d(out_size),
        nn.ReLU(),
#         nn.Dropout(p=p),
    )

fc_model = nn.Sequential(
#         nn.Dropout(p=0.5),
        fc_bc_relu_dropout(1000, 256, 0.5),
        fc_bc_relu_dropout(256, 128, 0.5),
        nn.Linear(128, OUTPUT_CLASSES),
#         nn.Softmax(-1),
    )

def weights_init(m):
    if isinstance(m, nn.Linear):
        nn.init.kaiming_normal_(m.weight)
        print(m)

print('init weights [nn.Linear] layers:')
fc_model.apply(weights_init)

model = nn.Sequential(
      efficientnet_b0(pretrained = True),
      fc_model,
    )
# Out:
# init weights [nn.Linear] layers:
# Linear(in_features=1000, out_features=256, bias=True)
# Linear(in_features=256, out_features=128, bias=True)
# Linear(in_features=128, out_features=3, bias=True)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

model = model.to(device)

# Assuming that we are on a CUDA machine, this should print a CUDA device:
print(device)
# Out:
# cuda:0

# %%
from torch.utils.data import DataLoader
from torch.utils.data import sampler
BATCH_SIZE = 64
train_dataset = MangoDataset(X_train, y_train, transform=transform)
train_dataloader = DataLoader(
    train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0)

val_dataset = MangoDataset(X_val, y_val)
val_dataloader = DataLoader(
    val_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0)

test_dataset = MangoDataset(X_test, y_test)
test_dataloader = DataLoader(
    test_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0)

# %%
# freeze pretrain weight
for p in model[0].parameters():
  # p.requires_grad = False
  p.requires_grad = True

# %%
def count_parameters(model):
    trainable_p = sum(p.numel() for p in model.parameters() if p.requires_grad)
    non_trainable_p = sum(p.numel() for p in model.parameters() if not p.requires_grad)
    return trainable_p, non_trainable_p

print('# of parameters')
trainable_p, non_trainable_p = count_parameters(model)
print('trainable:     %15s' % format(trainable_p, ','))
print('non-trainable: %15s' % (format(non_trainable_p, ',')))
# Out:
# # of parameters
# trainable:           5,578,855
# non-trainable:               0

# %%
import torch.optim as optim

CE_loss = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.00005, weight_decay=8e-3) #B0
scheduler = optim.lr_scheduler.MultiStepLR(
    optimizer, milestones=[10,20,40], gamma=0.9)

# %%
EPOCH = 50
history = History()

for epoch in range(EPOCH):  # loop over the dataset multiple times    
    n_batches = len(train_dataloader)
    print(f'Epoch {epoch+1}/{EPOCH}')
    pbar = tf.keras.utils.Progbar(target=n_batches)
    for i, data in enumerate(train_dataloader):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data[0].to(device, dtype=dtype), data[1].to(device, dtype=dtype)
        # zero the parameter gradients
        optimizer.zero_grad()
        # forward + backward + optimize
        outputs = model(inputs)

        loss = CE_loss(outputs, labels)
        loss.backward()
        
        optimizer.step()

        accuracy = calculate_accuracy(outputs, labels)
        loss = float(loss)
        
        pbar.update(i, values=[("train_loss", loss),
                    ("train_acc", accuracy)])
        
        history.batch_train(loss, accuracy)

    if scheduler.__module__ == 'torch.optim.lr_scheduler':
        scheduler.step()
        
    val_acc, val_loss, _ = validation(model, val_dataloader)            
    pbar.update(n_batches, values=[('val_loss', val_loss), ('val_acc', val_acc)])
    
    history.epoch_train(n_batches)
    history.epoch_val(val_loss, val_acc)

print('Finished Training')
# Out:
# Epoch 1/50
# 79/79 [==============================] - 38s 431ms/step - train_loss: 1.0229 - train_acc: 0.5059 - val_loss: 0.8318 - val_acc: 0.6339
# Epoch 2/50
# 79/79 [==============================] - 34s 423ms/step - train_loss: 0.7363 - train_acc: 0.6693 - val_loss: 0.7242 - val_acc: 0.6679
# Epoch 3/50
# 79/79 [==============================] - 34s 424ms/step - train_loss: 0.6582 - train_acc: 0.7097 - val_loss: 0.6971 - val_acc: 0.6875
# Epoch 4/50
# 79/79 [==============================] - 34s 423ms/step - train_loss: 0.6117 - train_acc: 0.7381 - val_loss: 0.6505 - val_acc: 0.6982
# Epoch 5/50
# 79/79 [==============================] - 34s 425ms/step - train_loss: 0.5717 - train_acc: 0.7584 - val_loss: 0.6497 - val_acc: 0.6893
# Epoch 6/50
# 79/79 [==============================] - 34s 424ms/step - train_loss: 0.5654 - train_acc: 0.7563 - val_loss: 0.6339 - val_acc: 0.7161
# Epoch 7/50
# 79/79 [==============================] - 34s 423ms/step - train_loss: 0.5385 - train_acc: 0.7709 - val_loss: 0.6276 - val_acc: 0.7089
# Epoch 8/50
# 79/79 [==============================] - 34s 425ms/step - train_loss: 0.5233 - train_acc: 0.7709 - val_loss: 0.6220 - val_acc: 0.7054
# Epoch 9/50
# 79/79 [==============================] - 34s 422ms/step - train_loss: 0.5202 - train_acc: 0.7790 - val_loss: 0.6213 - val_acc: 0.7143
# Epoch 10/50
# 79/79 [==============================] - 34s 424ms/step - train_loss: 0.4955 - train_acc: 0.7878 - val_loss: 0.6232 - val_acc: 0.7161
# Epoch 11/50
# 79/79 [==============================] - 34s 424ms/step - train_loss: 0.4774 - train_acc: 0.7961 - val_loss: 0.6156 - val_acc: 0.7286
# Epoch 12/50
# 79/79 [==============================] - 34s 423ms/step - train_loss: 0.4728 - train_acc: 0.7966 - val_loss: 0.6116 - val_acc: 0.7321
# Epoch 13/50
# 79/79 [==============================] - 34s 424ms/step - train_loss: 0.4602 - train_acc: 0.8050 - val_loss: 0.6759 - val_acc: 0.7036
# Epoch 14/50
# 79/79 [==============================] - 34s 425ms/step - train_loss: 0.4532 - train_acc: 0.8087 - val_loss: 0.5941 - val_acc: 0.7339
# Epoch 15/50
# 79/79 [==============================] - 34s 424ms/step - train_loss: 0.4459 - train_acc: 0.8143 - val_loss: 0.5884 - val_acc: 0.7411
# Epoch 16/50
# 79/79 [==============================] - 34s 425ms/step - train_loss: 0.4342 - train_acc: 0.8139 - val_loss: 0.6377 - val_acc: 0.7036
# Epoch 17/50
# 79/79 [==============================] - 34s 425ms/step - train_loss: 0.4411 - train_acc: 0.8122 - val_loss: 0.5863 - val_acc: 0.7429
# Epoch 18/50
# 79/79 [==============================] - 34s 423ms/step - train_loss: 0.4238 - train_acc: 0.8213 - val_loss: 0.6149 - val_acc: 0.7196
# Epoch 19/50
# 79/79 [==============================] - 34s 423ms/step - train_loss: 0.4267 - train_acc: 0.8188 - val_loss: 0.6078 - val_acc: 0.7339
# Epoch 20/50
# 79/79 [==============================] - 34s 422ms/step - train_loss: 0.4110 - train_acc: 0.8258 - val_loss: 0.5971 - val_acc: 0.7571
# Epoch 21/50
# 79/79 [==============================] - 34s 423ms/step - train_loss: 0.4163 - train_acc: 0.8225 - val_loss: 0.6534 - val_acc: 0.7107
# Epoch 22/50
# 79/79 [==============================] - 34s 423ms/step - train_loss: 0.3964 - train_acc: 0.8333 - val_loss: 0.5940 - val_acc: 0.7464
# Epoch 23/50
# 79/79 [==============================] - 34s 423ms/step - train_loss: 0.3980 - train_acc: 0.8319 - val_loss: 0.6041 - val_acc: 0.7393
# Epoch 24/50
# 79/79 [==============================] - 34s 426ms/step - train_loss: 0.4027 - train_acc: 0.8264 - val_loss: 0.6156 - val_acc: 0.7518
# Epoch 25/50
# 79/79 [==============================] - 34s 424ms/step - train_loss: 0.4045 - train_acc: 0.8304 - val_loss: 0.6141 - val_acc: 0.7339
# Epoch 26/50
# 79/79 [==============================] - 34s 424ms/step - train_loss: 0.3870 - train_acc: 0.8366 - val_loss: 0.5975 - val_acc: 0.7589
# Epoch 27/50
# 79/79 [==============================] - 34s 423ms/step - train_loss: 0.3940 - train_acc: 0.8361 - val_loss: 0.6036 - val_acc: 0.7268
# Epoch 28/50
# 79/79 [==============================] - 34s 425ms/step - train_loss: 0.3951 - train_acc: 0.8341 - val_loss: 0.6236 - val_acc: 0.7304
# Epoch 29/50
# 79/79 [==============================] - 34s 425ms/step - train_loss: 0.4007 - train_acc: 0.8333 - val_loss: 0.6023 - val_acc: 0.7393
# Epoch 30/50
# 79/79 [==============================] - 34s 425ms/step - train_loss: 0.3917 - train_acc: 0.8341 - val_loss: 0.5791 - val_acc: 0.7357
# Epoch 31/50
# 79/79 [==============================] - 34s 423ms/step - train_loss: 0.3864 - train_acc: 0.8439 - val_loss: 0.5963 - val_acc: 0.7304
# Epoch 32/50
# 79/79 [==============================] - 34s 425ms/step - train_loss: 0.3815 - train_acc: 0.8378 - val_loss: 0.6053 - val_acc: 0.7339
# Epoch 33/50
# 79/79 [==============================] - 34s 426ms/step - train_loss: 0.4034 - train_acc: 0.8255 - val_loss: 0.6077 - val_acc: 0.7250
# Epoch 34/50
# 79/79 [==============================] - 34s 423ms/step - train_loss: 0.3864 - train_acc: 0.8330 - val_loss: 0.6008 - val_acc: 0.7464
# Epoch 35/50
# 79/79 [==============================] - 34s 423ms/step - train_loss: 0.3795 - train_acc: 0.8420 - val_loss: 0.6133 - val_acc: 0.7214
# Epoch 36/50
# 79/79 [==============================] - 34s 423ms/step - train_loss: 0.3880 - train_acc: 0.8387 - val_loss: 0.6030 - val_acc: 0.7536
# Epoch 37/50
# 79/79 [==============================] - 34s 426ms/step - train_loss: 0.3823 - train_acc: 0.8329 - val_loss: 0.5947 - val_acc: 0.7464
# Epoch 38/50
# 79/79 [==============================] - 34s 424ms/step - train_loss: 0.3911 - train_acc: 0.8345 - val_loss: 0.6070 - val_acc: 0.7375
# Epoch 39/50
# 79/79 [==============================] - 34s 425ms/step - train_loss: 0.3824 - train_acc: 0.8364 - val_loss: 0.6596 - val_acc: 0.7071
# Epoch 40/50
# 79/79 [==============================] - 34s 424ms/step - train_loss: 0.3942 - train_acc: 0.8385 - val_loss: 0.5933 - val_acc: 0.7571
# Epoch 41/50
# 79/79 [==============================] - 34s 425ms/step - train_loss: 0.3783 - train_acc: 0.8424 - val_loss: 0.6101 - val_acc: 0.7429
# Epoch 42/50
# 79/79 [==============================] - 34s 426ms/step - train_loss: 0.3793 - train_acc: 0.8383 - val_loss: 0.6900 - val_acc: 0.6946
# Epoch 43/50
# 79/79 [==============================] - 34s 427ms/step - train_loss: 0.3790 - train_acc: 0.8391 - val_loss: 0.6256 - val_acc: 0.7446
# Epoch 44/50
# 79/79 [==============================] - 34s 424ms/step - train_loss: 0.3921 - train_acc: 0.8378 - val_loss: 0.6174 - val_acc: 0.7357
# Epoch 45/50
# 79/79 [==============================] - 34s 425ms/step - train_loss: 0.3924 - train_acc: 0.8364 - val_loss: 0.6570 - val_acc: 0.7214
# Epoch 46/50
# 79/79 [==============================] - 34s 425ms/step - train_loss: 0.3766 - train_acc: 0.8395 - val_loss: 0.6040 - val_acc: 0.7446
# Epoch 47/50
# 79/79 [==============================] - 34s 424ms/step - train_loss: 0.3830 - train_acc: 0.8364 - val_loss: 0.6668 - val_acc: 0.7429
# Epoch 48/50
# 79/79 [==============================] - 34s 424ms/step - train_loss: 0.3854 - train_acc: 0.8404 - val_loss: 0.5980 - val_acc: 0.7518
# Epoch 49/50
# 79/79 [==============================] - 34s 423ms/step - train_loss: 0.4058 - train_acc: 0.8250 - val_loss: 0.6736 - val_acc: 0.7518
# Epoch 50/50
# 79/79 [==============================] - 34s 422ms/step - train_loss: 0.3844 - train_acc: 0.8355 - val_loss: 0.6632 - val_acc: 0.7304
# Finished Training

# %%
test_acc, test_loss, y_true_pred = validation(model, test_dataloader)
print(f"Test Accuracy = %.4f" % test_acc)
# Out:
# Test Accuracy = 0.7575

# %%
val_acc, val_loss, _ = validation(model, val_dataloader)
print(f"Validation Accuracy = %.4f" % val_acc)
# Out:
# Validation Accuracy = 0.7304

# %%
import matplotlib.pyplot as plt

plt.plot(history.train_loss, label='train') 
plt.plot(history.val_loss, label='val') 
plt.title("Training / Val loss history")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(linestyle="--", linewidth=0.5)
plt.show()

# %%
plt.plot(history.train_acc, label='train') 
plt.plot(history.val_acc, label='val') 
plt.title("Training / Val Accuracy history")
plt.xlabel("Epoch") # 這裡應該要是epoch
plt.ylabel("Accuracy")
plt.legend()
plt.grid(linestyle="--", linewidth=0.5)
plt.show()

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
def make_confusion_matrix(y_true, y_score):
    cm = confusion_matrix(y_true, y_score)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['A', 'B', 'C']) #
    disp.plot()
    return cm

# %%
y_true, y_pred = y_true_pred
y_true = torch.cat(([y_true[i] for i in range(len(y_true))]))
y_pred = torch.cat(([y_pred[i] for i in range(len(y_pred))]))
y_true = y_true.cpu()
y_pred = y_pred.cpu()

# %%
make_confusion_matrix(y_true, y_pred)
# Out:
# array([[207,  59,  22],
#        [ 34, 221,  41],
#        [  6,  32, 178]], dtype=int64)

# %%
from sklearn import metrics
print(metrics.classification_report(y_true, y_pred, digits=3, target_names=["A","B","C"]))
# Out:
#               precision    recall  f1-score   support
#
#            A      0.838     0.719     0.774       288
#            B      0.708     0.747     0.727       296
#            C      0.739     0.824     0.779       216
#
#     accuracy                          0.757       800
#    macro avg      0.762     0.763     0.760       800
# weighted avg      0.763     0.757     0.758       800

# %%
torch.save(model, 'model/eff_b0_pretrain_aug_NoDrop.pt')
