# %%
# # This mounts your Google Drive to the Colab VM.
# from google.colab import drive
# drive.mount('/content/drive')
# !cp "/content/drive/MyDrive/AI芒果辨識競賽/C1-P1_Train Dev.rar" "/content/"

# %%
# !mkdir "mango"
# !unrar x "C1-P1_Train Dev.rar" "mango"

# %%
DATA_DIR = 'data/mango'

# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"

import shutil
import cv2
from PIL import Image
from tqdm.notebook import tqdm
import numpy as np
import pandas as pd
from torchvision.io import read_image
from torchvision import transforms, datasets
from torchvision.models import efficientnet_b3, efficientnet_b0, efficientnet_b6
import torch
from torch.utils.data import Dataset
from torch.nn import ZeroPad2d
import matplotlib.pyplot as plt
import tensorflow as tf

PADDING_SIZE = 1536
IMG_SHAPE = (224, 224)
# BATCH_SIZE = 512
OUTPUT_CLASSES = 3
MEAN = [55.49694383, 60.2820865, 82.53554147]
STD = [65.72940478, 67.66902771, 87.42390442]
dtype = torch.float32

# %%
class History:
    def __init__(self):
        self.train_loss = []
        self.val_loss = []
        self.train_acc = []
        self.val_acc = []
        self.running_loss = 0
        self.running_acc = 0
        
    def batch_train(self, batch_loss, batch_acc):
        self.running_loss += batch_loss
        self.running_acc += batch_acc
        
    def epoch_train(self, batch_num):
        self.train_loss.append(self.running_loss / batch_num)
        self.train_acc.append(self.running_acc / batch_num)
        self.running_loss = 0
        self.running_acc = 0
        
    def epoch_val(self, val_loss, val_acc):
        self.val_loss.append(val_loss)
        self.val_acc.append(val_acc)


def calculate_accuracy(y_pred, y_true):
    # y_pred y_true要是2D array (每筆資料的label的onehot encoding)
    y_pred = y_pred.argmax(axis=1)
    y_true = y_true.argmax(axis=1)
    correct = (y_pred == y_true).float().sum()
    accuracy = correct / len(y_true)
    return float(accuracy)

def validation(model, loader):
    num_correct = 0
    num_samples = 0
    loss = 0.0
    all_y_true = []
    all_y_pred = []
    model.eval()  # set model to evaluation mode
    with torch.no_grad():
        for x, y in loader:
            x = x.to(device=device, dtype=dtype)  # move to device, e.g. GPU
            y_true = y.to(device=device, dtype=dtype).argmax(axis=1)
            scores = model(x)      
            _, preds = scores.max(1)
            num = preds.size(0)
            loss += CE_loss(scores, y_true) * num
            
            all_y_true.append(y_true)
            all_y_pred.append(preds)

            num_correct += (preds == y_true).sum()
            num_samples += num
    acc = float(num_correct) / num_samples
    loss = float(loss / num_samples)
    return acc, loss, (all_y_true, all_y_pred)

# %%
def read_data(which="train"):
    data_dir = None
    y = None
    if which == "train":
        data_dir = os.path.join(DATA_DIR, "C1-P1_Train")
        label_csv = os.path.join(DATA_DIR, "train.csv")
    elif which == "test":
        data_dir = os.path.join(DATA_DIR, "C1-P1_Dev")
        label_csv = os.path.join(DATA_DIR, "dev.csv")
    else:
        print('input should be train or test')
        return

    X = []
    y = pd.get_dummies(pd.read_csv(label_csv, header=None)[1]).to_numpy()

    filenames = sorted(os.listdir(data_dir))  
    for filename in tqdm(filenames):
        fpath = os.path.join(data_dir, filename)
        img = cv2.imread(fpath)
        h,w,_ = img.shape
        top = int((PADDING_SIZE - h)/2)
        botoom = PADDING_SIZE - h - top
        left = int((PADDING_SIZE - w)/2)
        right = PADDING_SIZE - w - left

        # img = (img - MEAN) / STD
        img = img.astype(np.float32)
        img = cv2.copyMakeBorder(img, top, botoom, left, right, cv2.BORDER_CONSTANT)
        img[top:PADDING_SIZE-botoom, left:PADDING_SIZE-right] = \
          (img[top:PADDING_SIZE-botoom, left:PADDING_SIZE-right] - MEAN) / STD

        img = cv2.resize(img, IMG_SHAPE)
        X.append(img)
        # display(Image.fromarray(img[:,:,::-1]))
        # break
  
    X = np.array(X)
    return X, y

# %%
# %%time
# X_train, y_train = read_data(which="train")
# X_test, y_test = read_data(which="test")

npy_dir = "./data"
X_train = np.load(os.path.join(npy_dir, 'X_train.npy'))
y_train = np.load(os.path.join(npy_dir, 'y_train.npy'))
X_test = np.load(os.path.join(npy_dir, 'X_test.npy'))
y_test = np.load(os.path.join(npy_dir, 'y_test.npy'))
# Out:
# Wall time: 912 ms

# %%
# npy_dir = "./data"
# np.save(os.path.join(npy_dir, 'X_train.npy'), X_train)
# np.save(os.path.join(npy_dir, 'y_train.npy'), y_train)
# np.save(os.path.join(npy_dir, 'X_test.npy'), X_test)
# np.save(os.path.join(npy_dir, 'y_test.npy'), y_test)

# %%
# from google.colab.patches import cv2_imshow
plt.figure(figsize=(12,8))
for i, img in enumerate(X_train[:3]):
#     print(f"第{i+1}張圖片:")
#     cv2_imshow(img*STD+MEAN)
#     img = img*STD+MEAN
#     img = img.astype(np.int32)
    ax = plt.subplot(1, 3, i+1)    
    plt.title(f"figure {i+1}")
    ax.imshow(img[:,:,::-1])

#     plt.imshow(img[:,:,::-1])

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(
    X_train, y_train, test_size=0.1, random_state=1028)

# %%
print("X_train.shape", X_train.shape)
print("y_train.shape", y_train.shape)
print("X_val.shape", X_val.shape)
print("y_val.shape", y_val.shape)
print("X_test.shape", X_test.shape)
print("y_test.shape", y_test.shape)
# Out:
# X_train.shape (5040, 224, 224, 3)
# y_train.shape (5040, 3)
# X_val.shape (560, 224, 224, 3)
# y_val.shape (560, 3)
# X_test.shape (800, 224, 224, 3)
# y_test.shape (800, 3)

# %% [markdown]
# mean [55.49694383 60.2820865  82.53554147]
#
# std [65.72940478 67.66902771 87.42390442]

# %%
# print("mean", X_train.mean(axis=(0,1,2)))
# print("std", np.sqrt(X_train.var(axis=(0,1,2))))

# %%
def pre_processing(X):
    X = X[:,:,:,::-1].transpose(0,3,1,2)
    X = torch.tensor(X.copy(), dtype=dtype)
    # X = torch.tensor(X, dtype=dtype)
    # f_norm = transforms.Normalize(
    #           mean=[55.49694383, 60.2820865, 82.53554147],
    #           std=[65.72940478, 67.66902771, 87.42390442])
    # X = f_norm(X)
    return X

class MangoDataset(Dataset):
    def __init__(self, X, y, transform=None, target_transform=None):
        # self.X = pre_processing(X)
        self.X = X
        self.y = torch.tensor(y)
        self.transform = transform
        self.target_transform = target_transform
        
    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        image =  self.X[idx]
        image = image[:,:,::-1].transpose(2,0,1)
        image = torch.tensor(image.copy(), dtype=dtype)
        label = self.y[idx]
        if self.transform:
            image = self.transform(image)
        if self.target_transform:
            label = self.target_transform(label)
        return image, label

# %%
data_aug = [
  transforms.RandomCrop((200, 200)),
  transforms.RandomHorizontalFlip(p=0.5),
  transforms.RandomVerticalFlip(p=0.5),
  transforms.RandomAffine(degrees=50, translate=(0.15, 0.15)),
#   transforms.ColorJitter(brightness=0.1, contrast=0.1, saturation=0.1),
]

transform = transforms.Compose([
  transforms.RandomOrder(data_aug),
])

# %%
X_train.shape
# Out:
# (5040, 224, 224, 3)

# %%
import torch.nn as nn
import torch.nn.functional as F

def fc_bc_relu_dropout(in_size, out_size, p=0.5):
    return nn.Sequential(
        nn.Linear(in_size, out_size),
        nn.BatchNorm1d(out_size),
        nn.ReLU(),
        nn.Dropout(p=p),
    )

fc_model = nn.Sequential(
        nn.Dropout(p=0.5),
        fc_bc_relu_dropout(1000, 256, 0.5),
        fc_bc_relu_dropout(256, 128, 0.5),
        nn.Linear(128, OUTPUT_CLASSES),
#         nn.Softmax(-1),
    )

def weights_init(m):
    if isinstance(m, nn.Linear):
        nn.init.kaiming_normal_(m.weight)
        print(m)

print('init weights [nn.Linear] layers:')
fc_model.apply(weights_init)

model = nn.Sequential(
      efficientnet_b0(pretrained = True),
      fc_model,
    )
# Out:
# init weights [nn.Linear] layers:
# Linear(in_features=1000, out_features=256, bias=True)
# Linear(in_features=256, out_features=128, bias=True)
# Linear(in_features=128, out_features=3, bias=True)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

model = model.to(device)

# Assuming that we are on a CUDA machine, this should print a CUDA device:
print(device)
# Out:
# cuda:0

# %%
from torch.utils.data import DataLoader
from torch.utils.data import sampler
BATCH_SIZE = 64
train_dataset = MangoDataset(X_train, y_train, transform=transform)
train_dataloader = DataLoader(
    train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0)

val_dataset = MangoDataset(X_val, y_val)
val_dataloader = DataLoader(
    val_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0)

test_dataset = MangoDataset(X_test, y_test)
test_dataloader = DataLoader(
    test_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0)

# %%
# freeze pretrain weight
for p in model[0].parameters():
  # p.requires_grad = False
  p.requires_grad = True

# %%
def count_parameters(model):
    trainable_p = sum(p.numel() for p in model.parameters() if p.requires_grad)
    non_trainable_p = sum(p.numel() for p in model.parameters() if not p.requires_grad)
    return trainable_p, non_trainable_p

print('# of parameters')
trainable_p, non_trainable_p = count_parameters(model)
print('trainable:     %15s' % format(trainable_p, ','))
print('non-trainable: %15s' % (format(non_trainable_p, ',')))
# Out:
# # of parameters
# trainable:           5,578,855
# non-trainable:               0

# %%
import torch.optim as optim

CE_loss = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.00005, weight_decay=0) #B0
scheduler = optim.lr_scheduler.MultiStepLR(
    optimizer, milestones=[10,20,40], gamma=0.9)

# %%
EPOCH = 50
history = History()

for epoch in range(EPOCH):  # loop over the dataset multiple times    
    n_batches = len(train_dataloader)
    print(f'Epoch {epoch+1}/{EPOCH}')
    pbar = tf.keras.utils.Progbar(target=n_batches)
    for i, data in enumerate(train_dataloader):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data[0].to(device, dtype=dtype), data[1].to(device, dtype=dtype)
        # zero the parameter gradients
        optimizer.zero_grad()
        # forward + backward + optimize
        outputs = model(inputs)

        loss = CE_loss(outputs, labels)
        loss.backward()
        
        optimizer.step()

        accuracy = calculate_accuracy(outputs, labels)
        loss = float(loss)
        
        pbar.update(i, values=[("train_loss", loss),
                    ("train_acc", accuracy)])
        
        history.batch_train(loss, accuracy)

    if scheduler.__module__ == 'torch.optim.lr_scheduler':
        scheduler.step()
        
    val_acc, val_loss, _ = validation(model, val_dataloader)            
    pbar.update(n_batches, values=[('val_loss', val_loss), ('val_acc', val_acc)])
    
    history.epoch_train(n_batches)
    history.epoch_val(val_loss, val_acc)

print('Finished Training')
# Out:
# Epoch 1/50
# 79/79 [==============================] - 38s 429ms/step - train_loss: 1.5442 - train_acc: 0.3726 - val_loss: 0.9929 - val_acc: 0.4875
# Epoch 2/50
# 79/79 [==============================] - 33s 413ms/step - train_loss: 0.8198 - train_acc: 0.6266 - val_loss: 0.8011 - val_acc: 0.6482
# Epoch 3/50
# 79/79 [==============================] - 33s 411ms/step - train_loss: 0.6728 - train_acc: 0.7030 - val_loss: 0.7174 - val_acc: 0.6857
# Epoch 4/50
# 79/79 [==============================] - 33s 407ms/step - train_loss: 0.6254 - train_acc: 0.7305 - val_loss: 0.6704 - val_acc: 0.6964
# Epoch 5/50
# 79/79 [==============================] - 32s 404ms/step - train_loss: 0.5977 - train_acc: 0.7453 - val_loss: 0.6651 - val_acc: 0.7000
# Epoch 6/50
# 79/79 [==============================] - 33s 407ms/step - train_loss: 0.5652 - train_acc: 0.7557 - val_loss: 0.6812 - val_acc: 0.6875
# Epoch 7/50
# 79/79 [==============================] - 32s 406ms/step - train_loss: 0.5520 - train_acc: 0.7653 - val_loss: 0.6489 - val_acc: 0.7179
# Epoch 8/50
# 79/79 [==============================] - 33s 407ms/step - train_loss: 0.5405 - train_acc: 0.7638 - val_loss: 0.6764 - val_acc: 0.6696
# Epoch 9/50
# 79/79 [==============================] - 32s 405ms/step - train_loss: 0.5097 - train_acc: 0.7841 - val_loss: 0.6603 - val_acc: 0.7125
# Epoch 10/50
# 79/79 [==============================] - 33s 407ms/step - train_loss: 0.4997 - train_acc: 0.7827 - val_loss: 0.6997 - val_acc: 0.6911
# Epoch 11/50
# 79/79 [==============================] - 32s 406ms/step - train_loss: 0.4814 - train_acc: 0.7929 - val_loss: 0.6460 - val_acc: 0.7196
# Epoch 12/50
# 79/79 [==============================] - 33s 408ms/step - train_loss: 0.4671 - train_acc: 0.8013 - val_loss: 0.6413 - val_acc: 0.7286
# Epoch 13/50
# 79/79 [==============================] - 33s 408ms/step - train_loss: 0.4465 - train_acc: 0.8094 - val_loss: 0.6809 - val_acc: 0.6875
# Epoch 14/50
# 79/79 [==============================] - 32s 406ms/step - train_loss: 0.4455 - train_acc: 0.8188 - val_loss: 0.6419 - val_acc: 0.7429
# Epoch 15/50
# 79/79 [==============================] - 33s 407ms/step - train_loss: 0.4239 - train_acc: 0.8211 - val_loss: 0.6456 - val_acc: 0.7321
# Epoch 16/50
# 79/79 [==============================] - 33s 407ms/step - train_loss: 0.4070 - train_acc: 0.8304 - val_loss: 0.6750 - val_acc: 0.7161
# Epoch 17/50
# 79/79 [==============================] - 33s 408ms/step - train_loss: 0.3891 - train_acc: 0.8385 - val_loss: 0.6784 - val_acc: 0.7286
# Epoch 18/50
# 79/79 [==============================] - 33s 407ms/step - train_loss: 0.3759 - train_acc: 0.8434 - val_loss: 0.6743 - val_acc: 0.7482
# Epoch 19/50
# 79/79 [==============================] - 33s 408ms/step - train_loss: 0.3654 - train_acc: 0.8461 - val_loss: 0.6817 - val_acc: 0.7464
# Epoch 20/50
# 79/79 [==============================] - 32s 406ms/step - train_loss: 0.3606 - train_acc: 0.8486 - val_loss: 0.6987 - val_acc: 0.7107
# Epoch 21/50
# 79/79 [==============================] - 33s 408ms/step - train_loss: 0.3296 - train_acc: 0.8632 - val_loss: 0.6769 - val_acc: 0.7571
# Epoch 22/50
# 79/79 [==============================] - 33s 408ms/step - train_loss: 0.3263 - train_acc: 0.8650 - val_loss: 0.7144 - val_acc: 0.7268
# Epoch 23/50
# 79/79 [==============================] - 33s 408ms/step - train_loss: 0.3022 - train_acc: 0.8801 - val_loss: 0.7590 - val_acc: 0.7232
# Epoch 24/50
# 79/79 [==============================] - 32s 406ms/step - train_loss: 0.2788 - train_acc: 0.8803 - val_loss: 0.7481 - val_acc: 0.7304
# Epoch 25/50
# 79/79 [==============================] - 33s 411ms/step - train_loss: 0.2783 - train_acc: 0.8873 - val_loss: 0.7310 - val_acc: 0.7411
# Epoch 26/50
# 79/79 [==============================] - 32s 406ms/step - train_loss: 0.2547 - train_acc: 0.9018 - val_loss: 0.7477 - val_acc: 0.7339
# Epoch 27/50
# 79/79 [==============================] - 33s 407ms/step - train_loss: 0.2337 - train_acc: 0.9103 - val_loss: 0.7831 - val_acc: 0.7357
# Epoch 28/50
# 79/79 [==============================] - 33s 411ms/step - train_loss: 0.2331 - train_acc: 0.9082 - val_loss: 0.7928 - val_acc: 0.7500
# Epoch 29/50
# 79/79 [==============================] - 33s 408ms/step - train_loss: 0.2164 - train_acc: 0.9167 - val_loss: 0.8610 - val_acc: 0.7286
# Epoch 30/50
# 79/79 [==============================] - 33s 411ms/step - train_loss: 0.2138 - train_acc: 0.9138 - val_loss: 0.8246 - val_acc: 0.7411
# Epoch 31/50
# 79/79 [==============================] - 33s 407ms/step - train_loss: 0.1916 - train_acc: 0.9274 - val_loss: 0.8137 - val_acc: 0.7429
# Epoch 32/50
# 79/79 [==============================] - 33s 408ms/step - train_loss: 0.1729 - train_acc: 0.9344 - val_loss: 0.9516 - val_acc: 0.7214
# Epoch 33/50
# 79/79 [==============================] - 33s 408ms/step - train_loss: 0.1774 - train_acc: 0.9314 - val_loss: 0.8697 - val_acc: 0.7304
# Epoch 34/50
# 79/79 [==============================] - 33s 408ms/step - train_loss: 0.1507 - train_acc: 0.9423 - val_loss: 0.9443 - val_acc: 0.7321
# Epoch 35/50
# 79/79 [==============================] - 32s 405ms/step - train_loss: 0.1326 - train_acc: 0.9513 - val_loss: 1.0282 - val_acc: 0.7321
# Epoch 36/50
# 79/79 [==============================] - 32s 406ms/step - train_loss: 0.1480 - train_acc: 0.9427 - val_loss: 1.1407 - val_acc: 0.6929
# Epoch 37/50
# 79/79 [==============================] - 33s 408ms/step - train_loss: 0.1496 - train_acc: 0.9434 - val_loss: 0.9878 - val_acc: 0.7375
# Epoch 38/50
# 79/79 [==============================] - 33s 408ms/step - train_loss: 0.1210 - train_acc: 0.9569 - val_loss: 1.0053 - val_acc: 0.7411
# Epoch 39/50
# 79/79 [==============================] - 33s 409ms/step - train_loss: 0.1169 - train_acc: 0.9556 - val_loss: 0.9659 - val_acc: 0.7286
# Epoch 40/50
# 79/79 [==============================] - 33s 407ms/step - train_loss: 0.1148 - train_acc: 0.9575 - val_loss: 0.9914 - val_acc: 0.7357
# Epoch 41/50
# 79/79 [==============================] - 33s 407ms/step - train_loss: 0.1052 - train_acc: 0.9642 - val_loss: 1.0081 - val_acc: 0.7464
# Epoch 42/50
# 79/79 [==============================] - 33s 409ms/step - train_loss: 0.0919 - train_acc: 0.9685 - val_loss: 1.0453 - val_acc: 0.7357
# Epoch 43/50
# 79/79 [==============================] - 33s 407ms/step - train_loss: 0.0790 - train_acc: 0.9703 - val_loss: 1.0862 - val_acc: 0.7304
# Epoch 44/50
# 79/79 [==============================] - 33s 407ms/step - train_loss: 0.0745 - train_acc: 0.9737 - val_loss: 1.2014 - val_acc: 0.7482
# Epoch 45/50
# 79/79 [==============================] - 33s 407ms/step - train_loss: 0.0819 - train_acc: 0.9694 - val_loss: 1.2077 - val_acc: 0.7250
# Epoch 46/50
# 79/79 [==============================] - 32s 405ms/step - train_loss: 0.0761 - train_acc: 0.9709 - val_loss: 1.1389 - val_acc: 0.7321
# Epoch 47/50
# 79/79 [==============================] - 33s 408ms/step - train_loss: 0.0701 - train_acc: 0.9768 - val_loss: 1.3029 - val_acc: 0.7500
# Epoch 48/50
# 79/79 [==============================] - 33s 409ms/step - train_loss: 0.0643 - train_acc: 0.9769 - val_loss: 1.2772 - val_acc: 0.7196
# Epoch 49/50
# 79/79 [==============================] - 33s 407ms/step - train_loss: 0.0677 - train_acc: 0.9751 - val_loss: 1.2820 - val_acc: 0.7268
# Epoch 50/50
# 79/79 [==============================] - 32s 405ms/step - train_loss: 0.0554 - train_acc: 0.9816 - val_loss: 1.2808 - val_acc: 0.7411
# Finished Training

# %%
test_acc, test_loss, y_true_pred = validation(model, test_dataloader)
print(f"Test Accuracy = %.4f" % test_acc)
# Out:
# Test Accuracy = 0.7500

# %%
val_acc, val_loss, _ = validation(model, val_dataloader)
print(f"Validation Accuracy = %.4f" % val_acc)
# Out:
# Validation Accuracy = 0.7411

# %%
import matplotlib.pyplot as plt

plt.plot(history.train_loss, label='train') 
plt.plot(history.val_loss, label='val') 
plt.title("Training / Val loss history")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(linestyle="--", linewidth=0.5)
plt.show()

# %%
plt.plot(history.train_acc, label='train') 
plt.plot(history.val_acc, label='val') 
plt.title("Training / Val Accuracy history")
plt.xlabel("Epoch") # 這裡應該要是epoch
plt.ylabel("Accuracy")
plt.legend()
plt.grid(linestyle="--", linewidth=0.5)
plt.show()

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
def make_confusion_matrix(y_true, y_score):
    cm = confusion_matrix(y_true, y_score)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['A', 'B', 'C']) #
    disp.plot()
    return cm

# %%
y_true, y_pred = y_true_pred
y_true = torch.cat(([y_true[i] for i in range(len(y_true))]))
y_pred = torch.cat(([y_pred[i] for i in range(len(y_pred))]))
y_true = y_true.cpu()
y_pred = y_pred.cpu()

# %%
make_confusion_matrix(y_true, y_pred)
# Out:
# array([[207,  64,  17],
#        [ 34, 216,  46],
#        [  8,  31, 177]], dtype=int64)

# %%
from sklearn import metrics
print(metrics.classification_report(y_true, y_pred, digits=3, target_names=["A","B","C"]))
# Out:
#               precision    recall  f1-score   support
#
#            A      0.831     0.719     0.771       288
#            B      0.695     0.730     0.712       296
#            C      0.738     0.819     0.776       216
#
#     accuracy                          0.750       800
#    macro avg      0.754     0.756     0.753       800
# weighted avg      0.755     0.750     0.750       800

# %%
torch.save(model, 'model/_pretrain_aug_drop_NoReg.pt')
